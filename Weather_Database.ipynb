# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import timeit
import datetime
import random
#Import the request library 
import requests

#import the API key 
from config import weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d92620dc4d497a7f35833a3bb191d662

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d92620dc4d497a7f35833a3bb191d662

# %%
#Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

#Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if(i % 50 ==0 and i>=50):
        set_count += 1
        record_count = 1
        
    #Create endpoint url for each city.
    city_url = url + "&q=" + city
        
    #log the url,record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
        
    #Add 1 to the record count.
    record_count += 1
        
    #Run an API request for each of the cities.
    try:
         #Parse the JSON and retrieve the data.
        city_weather = requests.get(city_url).json()
        #Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description=city_weather["weather"][0]["description"]
            
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
            
            
        #Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Date": city_date,
                            "Lat": city_lat,
                             "Lng": city_lng,
                             "Max Temp": city_max_temp,
                             "Humidity": city_humidity,
                             "Cloudiness": city_clouds,
                             "Wind Speed": city_wind,                                                         
                             "Current Description":city_weather_description})
    #If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
#Indicate the data loading is complete.
print("------------------------------")
print("Data Retrieval Complete       ")
print("------------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | quatre cocos
# Processing Record 2 of Set 1 | kahului
# Processing Record 3 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 1 | tiksi
# Processing Record 8 of Set 1 | livingston
# Processing Record 9 of Set 1 | nanyang
# Processing Record 10 of Set 1 | khatanga
# Processing Record 11 of Set 1 | novokruchininskiy
# Processing Record 12 of Set 1 | iqaluit
# Processing Record 13 of Set 1 | punta arenas
# Processing Record 14 of Set 1 | upernavik
# Processing Record 15 of Set 1 | tabas
# Processing Record 16 of Set 1 | jumla
# Processing Record 17 of Set 1 | saint george
# Processing Record 18 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 19 of Set 1 | lagoa
# Processing Record 20 of Set 1 | saldanha
# Processing Record 21 of Set 1 | karratha
# Processing Record 22 of Set 1 | shirokiy
# Processing Record 23 of Set 1 | kavaratti
# Processing Record 24 of Set 1 | swan river
# Processing Record 25 of Set 1 | torbay
# Processing Record 26 of Set 1 | mazatlan
# Processing Record 27 of Set 1 | arraial do cabo
# Processing Record 28 of Set 1 | pevek
# Processing Record 29 of Set 1 | avarua
# Processing Record 30 of Set 1 | aitape
# Processing Record 31 of Set 1 | ushuaia
# Processing Record 32 of Set 1 | fare
# Processing Record 33 of Set 1 | gvarv
# Processing Record 34 of Set 1 | svobodnyy
# Processing Record 35 of Set 1 | sabang
# Processing Record 36 of Set 1 | irimbo
# Processing Record 37 of Set 1 | hilo
# Processing Record 38 of Set 1 | atuona
# Processing Record 39 of Set 1 | tasiilaq
# Processing Record 40 of Set 1 | muli
# Processing Record 41 of Set 1 | port elizabeth
# Processing Record 42 of Set 1 | howard springs
# Processing Record 43 of Set 1 | chokurdakh
# Processing Record 44 of Set 1 | stolin
# Processing Record 45 of Set 1 | vanimo
# Processing Record 46 of Set 1 | la asuncion
# Processing Record 47 of Set 1 | mandera
# Processing Record 48 of Set 1 | russell
# Processing Record 49 of Set 1 | sirpur
# Processing Record 50 of Set 1 | segezha
# Processing Record 1 of Set 2 | victoria
# Processing Record 2 of Set 2 | caravelas
# Processing Record 3 of Set 2 | quattro castella
# Processing Record 4 of Set 2 | airai
# Processing Record 5 of Set 2 | qaanaaq
# Processing Record 6 of Set 2 | albany
# Processing Record 7 of Set 2 | paytug
# City not found. Skipping...
# Processing Record 8 of Set 2 | new norfolk
# Processing Record 9 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 2 | faanui
# Processing Record 11 of Set 2 | tasbuget
# City not found. Skipping...
# Processing Record 12 of Set 2 | penzance
# Processing Record 13 of Set 2 | kaoma
# Processing Record 14 of Set 2 | saint-augustin
# Processing Record 15 of Set 2 | bireun
# Processing Record 16 of Set 2 | lucapa
# Processing Record 17 of Set 2 | vaini
# Processing Record 18 of Set 2 | tuy hoa
# Processing Record 19 of Set 2 | rikitea
# Processing Record 20 of Set 2 | tuktoyaktuk
# Processing Record 21 of Set 2 | waingapu
# Processing Record 22 of Set 2 | matadi
# Processing Record 23 of Set 2 | cape town
# Processing Record 24 of Set 2 | srednekolymsk
# Processing Record 25 of Set 2 | cherskiy
# Processing Record 26 of Set 2 | palmer
# Processing Record 27 of Set 2 | nisia floresta
# Processing Record 28 of Set 2 | dolbeau
# City not found. Skipping...
# Processing Record 29 of Set 2 | willowmore
# Processing Record 30 of Set 2 | yanan
# City not found. Skipping...
# Processing Record 31 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 32 of Set 2 | bubaque
# Processing Record 33 of Set 2 | salalah
# Processing Record 34 of Set 2 | butaritari
# Processing Record 35 of Set 2 | puerto ayora
# Processing Record 36 of Set 2 | nelson bay
# Processing Record 37 of Set 2 | kabompo
# Processing Record 38 of Set 2 | hithadhoo
# Processing Record 39 of Set 2 | ahome
# Processing Record 40 of Set 2 | sao jose da coroa grande
# Processing Record 41 of Set 2 | gulabpura
# Processing Record 42 of Set 2 | east london
# Processing Record 43 of Set 2 | soller
# Processing Record 44 of Set 2 | lucea
# Processing Record 45 of Set 2 | mataura
# Processing Record 46 of Set 2 | la baule-escoublac
# Processing Record 47 of Set 2 | jamestown
# Processing Record 48 of Set 2 | bodden town
# Processing Record 49 of Set 2 | atasu
# Processing Record 50 of Set 2 | kapaa
# Processing Record 1 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 2 of Set 3 | berlevag
# Processing Record 3 of Set 3 | siocon
# Processing Record 4 of Set 3 | bluff
# Processing Record 5 of Set 3 | chunskiy
# Processing Record 6 of Set 3 | mehamn
# Processing Record 7 of Set 3 | sitka
# Processing Record 8 of Set 3 | hofn
# Processing Record 9 of Set 3 | matiari
# Processing Record 10 of Set 3 | beringovskiy
# Processing Record 11 of Set 3 | salihorsk
# Processing Record 12 of Set 3 | luderitz
# Processing Record 13 of Set 3 | killybegs
# Processing Record 14 of Set 3 | morris
# Processing Record 15 of Set 3 | coquimbo
# Processing Record 16 of Set 3 | northam
# Processing Record 17 of Set 3 | provideniya
# Processing Record 18 of Set 3 | hasaki
# Processing Record 19 of Set 3 | jhabua
# Processing Record 20 of Set 3 | nanortalik
# Processing Record 21 of Set 3 | mar del plata
# Processing Record 22 of Set 3 | pangnirtung
# Processing Record 23 of Set 3 | aswan
# Processing Record 24 of Set 3 | presidencia roque saenz pena
# Processing Record 25 of Set 3 | puerto escondido
# Processing Record 26 of Set 3 | bredasdorp
# Processing Record 27 of Set 3 | wanning
# Processing Record 28 of Set 3 | thompson
# Processing Record 29 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 3 | porto novo
# Processing Record 31 of Set 3 | carutapera
# Processing Record 32 of Set 3 | cavalcante
# Processing Record 33 of Set 3 | hvolsvollur
# Processing Record 34 of Set 3 | padang
# Processing Record 35 of Set 3 | avera
# Processing Record 36 of Set 3 | hamilton
# Processing Record 37 of Set 3 | viedma
# Processing Record 38 of Set 3 | linkou
# Processing Record 39 of Set 3 | hermanus
# Processing Record 40 of Set 3 | alice springs
# Processing Record 41 of Set 3 | yellowknife
# Processing Record 42 of Set 3 | tuatapere
# Processing Record 43 of Set 3 | cidreira
# Processing Record 44 of Set 3 | portland
# Processing Record 45 of Set 3 | ostrovnoy
# Processing Record 46 of Set 3 | lichinga
# Processing Record 47 of Set 3 | ilulissat
# Processing Record 48 of Set 3 | port alfred
# Processing Record 49 of Set 3 | aklavik
# Processing Record 50 of Set 3 | dikson
# Processing Record 1 of Set 4 | kirakira
# Processing Record 2 of Set 4 | sao joao da barra
# Processing Record 3 of Set 4 | sabha
# Processing Record 4 of Set 4 | metro
# Processing Record 5 of Set 4 | boende
# Processing Record 6 of Set 4 | mandalgovi
# Processing Record 7 of Set 4 | tabou
# Processing Record 8 of Set 4 | martinsburg
# Processing Record 9 of Set 4 | cockburn town
# Processing Record 10 of Set 4 | leningradskiy
# Processing Record 11 of Set 4 | smithers
# Processing Record 12 of Set 4 | lebu
# Processing Record 13 of Set 4 | storm lake
# Processing Record 14 of Set 4 | hobart
# Processing Record 15 of Set 4 | castro
# Processing Record 16 of Set 4 | magadan
# Processing Record 17 of Set 4 | binzhou
# Processing Record 18 of Set 4 | neiafu
# Processing Record 19 of Set 4 | bojaya
# City not found. Skipping...
# Processing Record 20 of Set 4 | ribeira grande
# Processing Record 21 of Set 4 | hudson bay
# Processing Record 22 of Set 4 | nishihara
# Processing Record 23 of Set 4 | mopti
# Processing Record 24 of Set 4 | makakilo city
# Processing Record 25 of Set 4 | jiddah
# City not found. Skipping...
# Processing Record 26 of Set 4 | narsaq
# Processing Record 27 of Set 4 | evans
# Processing Record 28 of Set 4 | kununurra
# Processing Record 29 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 30 of Set 4 | carnarvon
# Processing Record 31 of Set 4 | santa rosa
# Processing Record 32 of Set 4 | olinda
# Processing Record 33 of Set 4 | matara
# Processing Record 34 of Set 4 | ligayan
# Processing Record 35 of Set 4 | port said
# Processing Record 36 of Set 4 | manaure
# Processing Record 37 of Set 4 | walvis bay
# Processing Record 38 of Set 4 | santana do mundau
# Processing Record 39 of Set 4 | saint-philippe
# Processing Record 40 of Set 4 | kuryk
# Processing Record 41 of Set 4 | kudahuvadhoo
# Processing Record 42 of Set 4 | inirida
# Processing Record 43 of Set 4 | esperance
# Processing Record 44 of Set 4 | papetoai
# Processing Record 45 of Set 4 | samur
# Processing Record 46 of Set 4 | vardo
# Processing Record 47 of Set 4 | bismarck
# Processing Record 48 of Set 4 | sarangani
# Processing Record 49 of Set 4 | tavda
# Processing Record 50 of Set 4 | kodiak
# Processing Record 1 of Set 5 | nikolskoye
# Processing Record 2 of Set 5 | lavrentiya
# Processing Record 3 of Set 5 | acapulco
# Processing Record 4 of Set 5 | bengkulu
# Processing Record 5 of Set 5 | beirut
# Processing Record 6 of Set 5 | lompoc
# Processing Record 7 of Set 5 | tambun
# Processing Record 8 of Set 5 | mount gambier
# Processing Record 9 of Set 5 | birin
# Processing Record 10 of Set 5 | marawi
# Processing Record 11 of Set 5 | tessalit
# Processing Record 12 of Set 5 | ryde
# Processing Record 13 of Set 5 | quelimane
# Processing Record 14 of Set 5 | lisieux
# Processing Record 15 of Set 5 | fortuna
# Processing Record 16 of Set 5 | dukat
# Processing Record 17 of Set 5 | mentok
# City not found. Skipping...
# Processing Record 18 of Set 5 | zhigansk
# Processing Record 19 of Set 5 | scalloway
# City not found. Skipping...
# Processing Record 20 of Set 5 | kaitangata
# Processing Record 21 of Set 5 | ruteng
# Processing Record 22 of Set 5 | talnakh
# Processing Record 23 of Set 5 | dingle
# Processing Record 24 of Set 5 | terrace bay
# Processing Record 25 of Set 5 | povenets
# Processing Record 26 of Set 5 | vila
# Processing Record 27 of Set 5 | floro
# Processing Record 28 of Set 5 | yumen
# Processing Record 29 of Set 5 | bonavista
# Processing Record 30 of Set 5 | deputatskiy
# Processing Record 31 of Set 5 | olafsvik
# Processing Record 32 of Set 5 | winnemucca
# Processing Record 33 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 34 of Set 5 | verkhoyansk
# Processing Record 35 of Set 5 | catabola
# Processing Record 36 of Set 5 | siniscola
# Processing Record 37 of Set 5 | shubarkuduk
# Processing Record 38 of Set 5 | constantine
# Processing Record 39 of Set 5 | conde
# Processing Record 40 of Set 5 | denia
# Processing Record 41 of Set 5 | college
# Processing Record 42 of Set 5 | mount isa
# Processing Record 43 of Set 5 | dali
# Processing Record 44 of Set 5 | zyryanskoye
# Processing Record 45 of Set 5 | ust-kulom
# Processing Record 46 of Set 5 | saint anthony
# Processing Record 47 of Set 5 | kandrian
# Processing Record 48 of Set 5 | uttaradit
# Processing Record 49 of Set 5 | georgetown
# Processing Record 50 of Set 5 | jalu
# Processing Record 1 of Set 6 | sinnamary
# Processing Record 2 of Set 6 | ulundi
# Processing Record 3 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 4 of Set 6 | yeltsovka
# City not found. Skipping...
# Processing Record 5 of Set 6 | snina
# Processing Record 6 of Set 6 | san quintin
# Processing Record 7 of Set 6 | rundu
# Processing Record 8 of Set 6 | bajos de haina
# Processing Record 9 of Set 6 | jiayuguan
# Processing Record 10 of Set 6 | shache
# Processing Record 11 of Set 6 | bonthe
# Processing Record 12 of Set 6 | bathsheba
# Processing Record 13 of Set 6 | cabo san lucas
# Processing Record 14 of Set 6 | yebaishou
# Processing Record 15 of Set 6 | nenagh
# Processing Record 16 of Set 6 | poum
# Processing Record 17 of Set 6 | severo-kurilsk
# Processing Record 18 of Set 6 | ahuimanu
# Processing Record 19 of Set 6 | zhezkazgan
# Processing Record 20 of Set 6 | paamiut
# Processing Record 21 of Set 6 | abha
# Processing Record 22 of Set 6 | ucluelet
# Processing Record 23 of Set 6 | inongo
# Processing Record 24 of Set 6 | ozgon
# City not found. Skipping...
# Processing Record 25 of Set 6 | noumea
# Processing Record 26 of Set 6 | jizan
# Processing Record 27 of Set 6 | ustek
# Processing Record 28 of Set 6 | ponta do sol
# Processing Record 29 of Set 6 | juneau
# Processing Record 30 of Set 6 | bilibino
# Processing Record 31 of Set 6 | manokwari
# Processing Record 32 of Set 6 | barrow
# Processing Record 33 of Set 6 | acarau
# Processing Record 34 of Set 6 | flinders
# Processing Record 35 of Set 6 | katha
# City not found. Skipping...
# Processing Record 36 of Set 6 | bossembele
# City not found. Skipping...
# Processing Record 37 of Set 6 | esso
# Processing Record 38 of Set 6 | padre bernardo
# Processing Record 39 of Set 6 | north bend
# Processing Record 40 of Set 6 | foumban
# Processing Record 41 of Set 6 | alto baudo
# City not found. Skipping...
# Processing Record 42 of Set 6 | pacific grove
# Processing Record 43 of Set 6 | pierre
# Processing Record 44 of Set 6 | skibbereen
# Processing Record 45 of Set 6 | sai buri
# Processing Record 46 of Set 6 | dubbo
# Processing Record 47 of Set 6 | minot
# Processing Record 48 of Set 6 | hirado
# Processing Record 49 of Set 6 | nueva gerona
# Processing Record 50 of Set 6 | wewak
# Processing Record 1 of Set 7 | anan
# Processing Record 2 of Set 7 | kidal
# Processing Record 3 of Set 7 | mahebourg
# Processing Record 4 of Set 7 | kloulklubed
# Processing Record 5 of Set 7 | kashi
# Processing Record 6 of Set 7 | otane
# Processing Record 7 of Set 7 | lorengau
# Processing Record 8 of Set 7 | hami
# Processing Record 9 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 10 of Set 7 | quimperle
# Processing Record 11 of Set 7 | lasa
# Processing Record 12 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 13 of Set 7 | colac
# Processing Record 14 of Set 7 | saint-joseph
# Processing Record 15 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 7 | tolaga bay
# Processing Record 17 of Set 7 | vanavara
# Processing Record 18 of Set 7 | jijiga
# Processing Record 19 of Set 7 | byron bay
# Processing Record 20 of Set 7 | veletma
# City not found. Skipping...
# Processing Record 21 of Set 7 | dudinka
# Processing Record 22 of Set 7 | bogorodskoye
# Processing Record 23 of Set 7 | joniskelis
# Processing Record 24 of Set 7 | harper
# Processing Record 25 of Set 7 | la ronge
# Processing Record 26 of Set 7 | aleksandrovsk-sakhalinskiy
# Processing Record 27 of Set 7 | qaqortoq
# Processing Record 28 of Set 7 | atherton
# Processing Record 29 of Set 7 | touros
# Processing Record 30 of Set 7 | houma
# Processing Record 31 of Set 7 | huilong
# Processing Record 32 of Set 7 | milkovo
# Processing Record 33 of Set 7 | waipawa
# Processing Record 34 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 35 of Set 7 | duluth
# Processing Record 36 of Set 7 | khash
# Processing Record 37 of Set 7 | kyren
# Processing Record 38 of Set 7 | kennewick
# Processing Record 39 of Set 7 | san joaquin
# Processing Record 40 of Set 7 | wladyslawowo
# Processing Record 41 of Set 7 | labuhan
# Processing Record 42 of Set 7 | niquelandia
# Processing Record 43 of Set 7 | kegayli
# City not found. Skipping...
# Processing Record 44 of Set 7 | tautira
# Processing Record 45 of Set 7 | djenne
# Processing Record 46 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 47 of Set 7 | gornopravdinsk
# Processing Record 48 of Set 7 | ijaki
# City not found. Skipping...
# Processing Record 49 of Set 7 | soloneshnoye
# Processing Record 50 of Set 7 | minab
# Processing Record 1 of Set 8 | nemuro
# Processing Record 2 of Set 8 | itaituba
# Processing Record 3 of Set 8 | los llanos de aridane
# Processing Record 4 of Set 8 | kiama
# Processing Record 5 of Set 8 | la orilla
# Processing Record 6 of Set 8 | kosa
# Processing Record 7 of Set 8 | manzhouli
# Processing Record 8 of Set 8 | katangli
# Processing Record 9 of Set 8 | fuzhou
# Processing Record 10 of Set 8 | xichang
# Processing Record 11 of Set 8 | straumen
# Processing Record 12 of Set 8 | pochutla
# Processing Record 13 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 14 of Set 8 | massaguet
# Processing Record 15 of Set 8 | eenhana
# Processing Record 16 of Set 8 | southbridge
# Processing Record 17 of Set 8 | sataua
# City not found. Skipping...
# Processing Record 18 of Set 8 | ruatoria
# City not found. Skipping...
# Processing Record 19 of Set 8 | luanda
# Processing Record 20 of Set 8 | sobolevo
# Processing Record 21 of Set 8 | daru
# Processing Record 22 of Set 8 | corinto
# Processing Record 23 of Set 8 | zonguldak
# Processing Record 24 of Set 8 | minsk mazowiecki
# Processing Record 25 of Set 8 | aasiaat
# Processing Record 26 of Set 8 | solnechnyy
# Processing Record 27 of Set 8 | santa maria
# Processing Record 28 of Set 8 | nassjo
# Processing Record 29 of Set 8 | san luis
# Processing Record 30 of Set 8 | itaporanga
# Processing Record 31 of Set 8 | camacha
# Processing Record 32 of Set 8 | hammerfest
# Processing Record 33 of Set 8 | lalomanu
# City not found. Skipping...
# Processing Record 34 of Set 8 | pundaguitan
# Processing Record 35 of Set 8 | shimoda
# Processing Record 36 of Set 8 | isangel
# Processing Record 37 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 38 of Set 8 | chuy
# Processing Record 39 of Set 8 | nador
# Processing Record 40 of Set 8 | uusikaupunki
# Processing Record 41 of Set 8 | longyearbyen
# Processing Record 42 of Set 8 | bambous virieux
# Processing Record 43 of Set 8 | nadvoitsy
# Processing Record 44 of Set 8 | mitu
# Processing Record 45 of Set 8 | luba
# Processing Record 46 of Set 8 | moron
# Processing Record 47 of Set 8 | palu
# Processing Record 48 of Set 8 | kuching
# Processing Record 49 of Set 8 | tarragona
# Processing Record 50 of Set 8 | peniche
# Processing Record 1 of Set 9 | fougamou
# Processing Record 2 of Set 9 | terney
# Processing Record 3 of Set 9 | saquena
# Processing Record 4 of Set 9 | bethel
# Processing Record 5 of Set 9 | nuevo casas grandes
# Processing Record 6 of Set 9 | xai-xai
# Processing Record 7 of Set 9 | cayenne
# Processing Record 8 of Set 9 | mariager
# Processing Record 9 of Set 9 | churapcha
# Processing Record 10 of Set 9 | sur
# Processing Record 11 of Set 9 | sawtell
# Processing Record 12 of Set 9 | sofiysk
# City not found. Skipping...
# Processing Record 13 of Set 9 | monroe
# Processing Record 14 of Set 9 | chenzhou
# Processing Record 15 of Set 9 | bundibugyo
# Processing Record 16 of Set 9 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 9 | trois-rivieres
# Processing Record 18 of Set 9 | waycross
# Processing Record 19 of Set 9 | laguna
# Processing Record 20 of Set 9 | abu kamal
# Processing Record 21 of Set 9 | ust-maya
# Processing Record 22 of Set 9 | pangobilian
# Processing Record 23 of Set 9 | tupik
# Processing Record 24 of Set 9 | klaksvik
# Processing Record 25 of Set 9 | tateyama
# Processing Record 26 of Set 9 | souillac
# Processing Record 27 of Set 9 | alta floresta
# Processing Record 28 of Set 9 | broome
# Processing Record 29 of Set 9 | faya
# Processing Record 30 of Set 9 | cabedelo
# Processing Record 31 of Set 9 | ambulu
# Processing Record 32 of Set 9 | mwene-ditu
# Processing Record 33 of Set 9 | nangal
# Processing Record 34 of Set 9 | taltal
# Processing Record 35 of Set 9 | vacaria
# Processing Record 36 of Set 9 | harrisonville
# Processing Record 37 of Set 9 | bac lieu
# Processing Record 38 of Set 9 | muscat
# Processing Record 39 of Set 9 | banda aceh
# Processing Record 40 of Set 9 | warrington
# Processing Record 41 of Set 9 | san nicolas
# Processing Record 42 of Set 9 | la serena
# Processing Record 43 of Set 9 | sao filipe
# Processing Record 44 of Set 9 | yar-sale
# Processing Record 45 of Set 9 | lima
# Processing Record 46 of Set 9 | nome
# Processing Record 47 of Set 9 | saryshagan
# City not found. Skipping...
# Processing Record 48 of Set 9 | pangody
# Processing Record 49 of Set 9 | paita
# Processing Record 50 of Set 9 | abu samrah
# Processing Record 1 of Set 10 | altay
# Processing Record 2 of Set 10 | manaus
# Processing Record 3 of Set 10 | marfino
# Processing Record 4 of Set 10 | coxim
# Processing Record 5 of Set 10 | ratnagiri
# Processing Record 6 of Set 10 | saint-francois
# Processing Record 7 of Set 10 | otjimbingwe
# Processing Record 8 of Set 10 | shaunavon
# Processing Record 9 of Set 10 | ust-omchug
# Processing Record 10 of Set 10 | kalavad
# Processing Record 11 of Set 10 | norman wells
# Processing Record 12 of Set 10 | asau
# Processing Record 13 of Set 10 | orlik
# Processing Record 14 of Set 10 | santarem
# Processing Record 15 of Set 10 | rocha
# Processing Record 16 of Set 10 | bosaso
# Processing Record 17 of Set 10 | hambantota
# Processing Record 18 of Set 10 | heinola
# Processing Record 19 of Set 10 | ksenyevka
# City not found. Skipping...
# Processing Record 20 of Set 10 | ancud
# Processing Record 21 of Set 10 | lodwar
# Processing Record 22 of Set 10 | irbeyskoye
# Processing Record 23 of Set 10 | fort nelson
# Processing Record 24 of Set 10 | clyde river
# Processing Record 25 of Set 10 | moberly
# Processing Record 26 of Set 10 | campbell river
# Processing Record 27 of Set 10 | chulym
# Processing Record 28 of Set 10 | naze
# Processing Record 29 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 30 of Set 10 | saskylakh
# Processing Record 31 of Set 10 | plettenberg bay
# Processing Record 32 of Set 10 | katherine
# Processing Record 33 of Set 10 | madang
# Processing Record 34 of Set 10 | gizo
# Processing Record 35 of Set 10 | hsichih
# City not found. Skipping...
# Processing Record 36 of Set 10 | tanabi
# Processing Record 37 of Set 10 | sakakah
# Processing Record 38 of Set 10 | hay river
# Processing Record 39 of Set 10 | kitimat
# Processing Record 40 of Set 10 | kulgam
# Processing Record 41 of Set 10 | jiaohe
# Processing Record 42 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 43 of Set 10 | bara
# Processing Record 44 of Set 10 | uray
# Processing Record 45 of Set 10 | jilikul
# Processing Record 46 of Set 10 | abbeville
# Processing Record 47 of Set 10 | nakamura
# Processing Record 48 of Set 10 | juifang
# City not found. Skipping...
# Processing Record 49 of Set 10 | turukhansk
# Processing Record 50 of Set 10 | mayo
# Processing Record 1 of Set 11 | ostersund
# Processing Record 2 of Set 11 | bandarbeyla
# Processing Record 3 of Set 11 | aykhal
# Processing Record 4 of Set 11 | meiktila
# Processing Record 5 of Set 11 | shaoxing
# Processing Record 6 of Set 11 | hualmay
# Processing Record 7 of Set 11 | gaoua
# Processing Record 8 of Set 11 | knysna
# Processing Record 9 of Set 11 | te anau
# Processing Record 10 of Set 11 | solsvik
# City not found. Skipping...
# Processing Record 11 of Set 11 | strezhevoy
# Processing Record 12 of Set 11 | port macquarie
# Processing Record 13 of Set 11 | soyo
# Processing Record 14 of Set 11 | tyukhtet
# Processing Record 15 of Set 11 | bealanana
# Processing Record 16 of Set 11 | cartagena del chaira
# Processing Record 17 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 18 of Set 11 | yulara
# Processing Record 19 of Set 11 | vagur
# Processing Record 20 of Set 11 | siyabuswa
# Processing Record 21 of Set 11 | tezu
# Processing Record 22 of Set 11 | sapapalii
# City not found. Skipping...
# Processing Record 23 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 24 of Set 11 | donji milanovac
# Processing Record 25 of Set 11 | tura
# Processing Record 26 of Set 11 | kobyzhcha
# Processing Record 27 of Set 11 | zinder
# Processing Record 28 of Set 11 | abalak
# Processing Record 29 of Set 11 | kavieng
# Processing Record 30 of Set 11 | balad
# Processing Record 31 of Set 11 | namibe
# Processing Record 32 of Set 11 | vaxjo
# Processing Record 33 of Set 11 | stoyba
# City not found. Skipping...
# Processing Record 34 of Set 11 | elko
# Processing Record 35 of Set 11 | mahajanga
# Processing Record 36 of Set 11 | bend
# Processing Record 37 of Set 11 | chenghai
# Processing Record 38 of Set 11 | cap malheureux
# Processing Record 39 of Set 11 | gat
# Processing Record 40 of Set 11 | pisco
# Processing Record 41 of Set 11 | half moon bay
# Processing Record 42 of Set 11 | salinopolis
# Processing Record 43 of Set 11 | baranain
# Processing Record 44 of Set 11 | adrar
# Processing Record 45 of Set 11 | korla
# Processing Record 46 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 47 of Set 11 | richards bay
# Processing Record 48 of Set 11 | yarmolyntsi
# Processing Record 49 of Set 11 | ketchikan
# Processing Record 50 of Set 11 | palauig
# Processing Record 1 of Set 12 | majene
# Processing Record 2 of Set 12 | soe
# Processing Record 3 of Set 12 | aksarka
# Processing Record 4 of Set 12 | ahipara
# Processing Record 5 of Set 12 | bardiyah
# Processing Record 6 of Set 12 | rafsanjan
# Processing Record 7 of Set 12 | ceres
# Processing Record 8 of Set 12 | kongsvinger
# Processing Record 9 of Set 12 | oktyabrskiy
# Processing Record 10 of Set 12 | rio grande
# Processing Record 11 of Set 12 | ferme-neuve
# Processing Record 12 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 13 of Set 12 | paka
# Processing Record 14 of Set 12 | rudnogorsk
# Processing Record 15 of Set 12 | altamont
# Processing Record 16 of Set 12 | kathu
# Processing Record 17 of Set 12 | port hardy
# Processing Record 18 of Set 12 | ust-tsilma
# Processing Record 19 of Set 12 | vila velha
# Processing Record 20 of Set 12 | bilma
# Processing Record 21 of Set 12 | sinazongwe
# Processing Record 22 of Set 12 | davenda
# Processing Record 23 of Set 12 | mae hong son
# Processing Record 24 of Set 12 | aripuana
# Processing Record 25 of Set 12 | sept-iles
# Processing Record 26 of Set 12 | kenai
# Processing Record 27 of Set 12 | surt
# Processing Record 28 of Set 12 | santa rosa de cabal
# Processing Record 29 of Set 12 | mahaicony
# City not found. Skipping...
# Processing Record 30 of Set 12 | port lincoln
# Processing Record 31 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 32 of Set 12 | tutoia
# Processing Record 33 of Set 12 | muscatine
# Processing Record 34 of Set 12 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 35 of Set 12 | minsk
# Processing Record 36 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 37 of Set 12 | zyryanka
# Processing Record 38 of Set 12 | meulaboh
# Processing Record 39 of Set 12 | pernik
# Processing Record 40 of Set 12 | mumford
# Processing Record 41 of Set 12 | alenquer
# Processing Record 42 of Set 12 | lianran
# Processing Record 43 of Set 12 | mana
# Processing Record 44 of Set 12 | seagoville
# Processing Record 45 of Set 12 | port hedland
# Processing Record 46 of Set 12 | ginda
# Processing Record 47 of Set 12 | turda
# Processing Record 48 of Set 12 | winslow
# Processing Record 49 of Set 12 | auki
# Processing Record 50 of Set 12 | ossora
# Processing Record 1 of Set 13 | gusau
# Processing Record 2 of Set 13 | bluefields
# Processing Record 3 of Set 13 | grand gaube
# Processing Record 4 of Set 13 | katsuura
# Processing Record 5 of Set 13 | verkhnetulomskiy
# Processing Record 6 of Set 13 | anadyr
# Processing Record 7 of Set 13 | samarai
# Processing Record 8 of Set 13 | koutsouras
# Processing Record 9 of Set 13 | margate
# Processing Record 10 of Set 13 | raudeberg
# Processing Record 11 of Set 13 | gobabis
# Processing Record 12 of Set 13 | nakambala
# Processing Record 13 of Set 13 | chardara
# Processing Record 14 of Set 13 | tromso
# Processing Record 15 of Set 13 | tual
# Processing Record 16 of Set 13 | trebukhiv
# Processing Record 17 of Set 13 | verin
# Processing Record 18 of Set 13 | tawkar
# City not found. Skipping...
# Processing Record 19 of Set 13 | zeya
# Processing Record 20 of Set 13 | novikovo
# Processing Record 21 of Set 13 | seoul
# Processing Record 22 of Set 13 | silopi
# Processing Record 23 of Set 13 | itoman
# Processing Record 24 of Set 13 | las palmas
# Processing Record 25 of Set 13 | maniitsoq
# Processing Record 26 of Set 13 | narayanavanam
# Processing Record 27 of Set 13 | carros
# Processing Record 28 of Set 13 | jalingo
# Processing Record 29 of Set 13 | charters towers
# Processing Record 30 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 31 of Set 13 | aktyubinskiy
# Processing Record 32 of Set 13 | kaniama
# Processing Record 33 of Set 13 | bairiki
# Processing Record 34 of Set 13 | bonfim
# Processing Record 35 of Set 13 | shingu
# Processing Record 36 of Set 13 | bosobolo
# Processing Record 37 of Set 13 | marshall
# Processing Record 38 of Set 13 | chapais
# Processing Record 39 of Set 13 | gorgan
# Processing Record 40 of Set 13 | kungurtug
# Processing Record 41 of Set 13 | skagastrond
# City not found. Skipping...
# Processing Record 42 of Set 13 | mineros
# Processing Record 43 of Set 13 | barao de melgaco
# Processing Record 44 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 45 of Set 13 | urengoy
# Processing Record 46 of Set 13 | geraldton
# Processing Record 47 of Set 13 | puerto madryn
# Processing Record 48 of Set 13 | aktau
# Processing Record 49 of Set 13 | caceres
# Processing Record 50 of Set 13 | huarmey
# Processing Record 1 of Set 14 | opmeer
# Processing Record 2 of Set 14 | itarema
# Processing Record 3 of Set 14 | fredericton
# Processing Record 4 of Set 14 | noyabrsk
# Processing Record 5 of Set 14 | fomboni
# Processing Record 6 of Set 14 | dryden
# Processing Record 7 of Set 14 | cairns
# Processing Record 8 of Set 14 | kadaya
# Processing Record 9 of Set 14 | bondo
# Processing Record 10 of Set 14 | biak
# Processing Record 11 of Set 14 | roma
# Processing Record 12 of Set 14 | dakar
# Processing Record 13 of Set 14 | melfi
# Processing Record 14 of Set 14 | buluang
# Processing Record 15 of Set 14 | goure
# Processing Record 16 of Set 14 | butembo
# Processing Record 17 of Set 14 | guerrero negro
# Processing Record 18 of Set 14 | grindavik
# Processing Record 19 of Set 14 | muros
# Processing Record 20 of Set 14 | terbuny
# Processing Record 21 of Set 14 | elliot lake
# Processing Record 22 of Set 14 | kijang
# Processing Record 23 of Set 14 | pathein
# Processing Record 24 of Set 14 | ochamchira
# Processing Record 25 of Set 14 | chumikan
# Processing Record 26 of Set 14 | brae
# Processing Record 27 of Set 14 | port blair
# Processing Record 28 of Set 14 | muisne
# Processing Record 29 of Set 14 | polunochnoye
# Processing Record 30 of Set 14 | kuito
# Processing Record 31 of Set 14 | kalomo
# City not found. Skipping...
# Processing Record 32 of Set 14 | arlit
# Processing Record 33 of Set 14 | havre-saint-pierre
# Processing Record 34 of Set 14 | marsaxlokk
# Processing Record 35 of Set 14 | hirara
# Processing Record 36 of Set 14 | shihezi
# Processing Record 37 of Set 14 | cururupu
# Processing Record 38 of Set 14 | montesarchio
# Processing Record 39 of Set 14 | nampa
# Processing Record 40 of Set 14 | villacarrillo
# Processing Record 41 of Set 14 | constitucion
# Processing Record 42 of Set 14 | mrirt
# City not found. Skipping...
# Processing Record 43 of Set 14 | ilmajoki
# Processing Record 44 of Set 14 | felidhoo
# City not found. Skipping...
# Processing Record 45 of Set 14 | shubarshi
# Processing Record 46 of Set 14 | kodinsk
# Processing Record 47 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 48 of Set 14 | konya
# Processing Record 49 of Set 14 | nivala
# Processing Record 50 of Set 14 | mpanda
# Processing Record 1 of Set 15 | bonnyville
# Processing Record 2 of Set 15 | vadso
# Processing Record 3 of Set 15 | solovetskiy
# City not found. Skipping...
# Processing Record 4 of Set 15 | omboue
# Processing Record 5 of Set 15 | jertih
# Processing Record 6 of Set 15 | freudenberg
# Processing Record 7 of Set 15 | san cristobal
# Processing Record 8 of Set 15 | lodja
# Processing Record 9 of Set 15 | motygino
# Processing Record 10 of Set 15 | dwarka
# Processing Record 11 of Set 15 | tomatlan
# Processing Record 12 of Set 15 | ukiah
# Processing Record 13 of Set 15 | guozhen
# Processing Record 14 of Set 15 | sirhind
# Processing Record 15 of Set 15 | bud
# Processing Record 16 of Set 15 | ulladulla
# Processing Record 17 of Set 15 | eldikan
# City not found. Skipping...
# Processing Record 18 of Set 15 | husavik
# Processing Record 19 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 20 of Set 15 | kommunar
# Processing Record 21 of Set 15 | erdenet
# Processing Record 22 of Set 15 | morant bay
# Processing Record 23 of Set 15 | slave lake
# Processing Record 24 of Set 15 | trofors
# Processing Record 25 of Set 15 | betong
# Processing Record 26 of Set 15 | antalaha
# Processing Record 27 of Set 15 | tricase
# Processing Record 28 of Set 15 | hervey bay
# Processing Record 29 of Set 15 | totoro
# Processing Record 30 of Set 15 | vao
# Processing Record 31 of Set 15 | tahe
# Processing Record 32 of Set 15 | gossas
# Processing Record 33 of Set 15 | weida
# Processing Record 34 of Set 15 | saint-georges
# Processing Record 35 of Set 15 | iznoski
# Processing Record 36 of Set 15 | batemans bay
# Processing Record 37 of Set 15 | manzanillo
# Processing Record 38 of Set 15 | garden city
# Processing Record 39 of Set 15 | hearst
# Processing Record 40 of Set 15 | coram
# Processing Record 41 of Set 15 | kalmunai
# Processing Record 42 of Set 15 | chifeng
# Processing Record 43 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 44 of Set 15 | mendahara
# City not found. Skipping...
# Processing Record 45 of Set 15 | agirish
# Processing Record 46 of Set 15 | ortona
# Processing Record 47 of Set 15 | yatou
# Processing Record 48 of Set 15 | port-gentil
# Processing Record 49 of Set 15 | khormuj
# City not found. Skipping...
# Processing Record 50 of Set 15 | caronport
# Processing Record 1 of Set 16 | semirom
# Processing Record 2 of Set 16 | zhuhai
# Processing Record 3 of Set 16 | karasjok
# Processing Record 4 of Set 16 | omsukchan
# Processing Record 5 of Set 16 | khryashchevka
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %%
len(city_data)
# Out:
# 685

# %%
#Create a city df
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                 City Country                 Date      Lat       Lng  \
# 0       Quatre Cocos      MU  2021-11-07 04:23:00 -20.2078   57.7625
# 1            Kahului      US  2021-11-07 04:23:00  20.8947 -156.4700
# 2          Busselton      AU  2021-11-07 04:23:01 -33.6500  115.3333
# 3              Tiksi      RU  2021-11-07 04:23:01  71.6872  128.8694
# 4         Livingston      GB  2021-11-07 04:18:59  55.9029   -3.5226
# 5            Nanyang      CN  2021-11-07 04:23:01  32.9947  112.5328
# 6           Khatanga      RU  2021-11-07 04:23:02  71.9667  102.5000
# 7  Novokruchininskiy      RU  2021-11-07 04:23:03  51.7833  113.7667
# 8            Iqaluit      CA  2021-11-07 04:23:03  63.7506  -68.5145
# 9       Punta Arenas      CL  2021-11-07 04:22:25 -53.1500  -70.9167
#
#    Max Temp  Humidity  Cloudiness  Wind Speed Current Description
# 0     81.09        77          43       14.41    scattered clouds
# 1     78.82        73           1       23.02           clear sky
# 2     66.43        41          44        4.23    scattered clouds
# 3      0.63        87         100       15.86     overcast clouds
# 4     46.76        72          75       16.11       broken clouds
# 5     44.98        55         100       10.67     overcast clouds
# 6      8.65        85         100        7.16     overcast clouds
# 7     26.33        42          26       11.50    scattered clouds
# 8     20.93        73          40       11.01    scattered clouds
# 9     48.31        87          90       11.50     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
