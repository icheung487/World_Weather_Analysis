# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import timeit
import datetime
import random
#Import the request library 
import requests

#import the API key 
from config import weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d92620dc4d497a7f35833a3bb191d662

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d92620dc4d497a7f35833a3bb191d662

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 739

# %%
#Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

#Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if(i % 50 ==0 and i>=50):
        set_count += 1
        record_count = 1
        
    #Create endpoint url for each city.
    city_url = url + "&q=" + city
        
    #log the url,record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
        
    #Add 1 to the record count.
    record_count += 1
        
    #Run an API request for each of the cities.
    try:
         #Parse the JSON and retrieve the data.
        city_weather = requests.get(city_url).json()
        #Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description=city_weather["weather"][0]["description"]
            
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
            
            
        #Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                            "Lat": city_lat,
                             "Lng": city_lng,
                             "Max Temp": city_max_temp,
                             "Humidity": city_humidity,
                             "Cloudiness": city_clouds,
                             "Wind Speed": city_wind,                                                         
                             "Current Description":city_weather_description})
    #If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
#Indicate the data loading is complete.
print("------------------------------")
print("Data Retrieval Complete       ")
print("------------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 2 of Set 1 | bethel
# Processing Record 3 of Set 1 | dikson
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | punta arenas
# Processing Record 7 of Set 1 | evensk
# Processing Record 8 of Set 1 | bluff
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | te anau
# Processing Record 11 of Set 1 | tasbuget
# City not found. Skipping...
# Processing Record 12 of Set 1 | arraial do cabo
# Processing Record 13 of Set 1 | kapaa
# Processing Record 14 of Set 1 | nanortalik
# Processing Record 15 of Set 1 | tiksi
# Processing Record 16 of Set 1 | ruteng
# Processing Record 17 of Set 1 | carnarvon
# Processing Record 18 of Set 1 | ygatimi
# Processing Record 19 of Set 1 | saint-philippe
# Processing Record 20 of Set 1 | nikolskoye
# Processing Record 21 of Set 1 | vaini
# Processing Record 22 of Set 1 | cape town
# Processing Record 23 of Set 1 | kotlas
# Processing Record 24 of Set 1 | maturin
# Processing Record 25 of Set 1 | vilhena
# Processing Record 26 of Set 1 | waingapu
# Processing Record 27 of Set 1 | san policarpo
# Processing Record 28 of Set 1 | sokolo
# Processing Record 29 of Set 1 | hithadhoo
# Processing Record 30 of Set 1 | bredasdorp
# Processing Record 31 of Set 1 | port macquarie
# Processing Record 32 of Set 1 | cerro largo
# Processing Record 33 of Set 1 | port elizabeth
# Processing Record 34 of Set 1 | pimenta bueno
# Processing Record 35 of Set 1 | albany
# Processing Record 36 of Set 1 | mahebourg
# Processing Record 37 of Set 1 | gravdal
# Processing Record 38 of Set 1 | koumac
# Processing Record 39 of Set 1 | faanui
# Processing Record 40 of Set 1 | torbay
# Processing Record 41 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 42 of Set 1 | mount gambier
# Processing Record 43 of Set 1 | norman wells
# Processing Record 44 of Set 1 | narsaq
# Processing Record 45 of Set 1 | jinka
# Processing Record 46 of Set 1 | kiliya
# Processing Record 47 of Set 1 | luderitz
# Processing Record 48 of Set 1 | warrington
# Processing Record 49 of Set 1 | san cristobal
# Processing Record 50 of Set 1 | cabo san lucas
# Processing Record 1 of Set 2 | khatanga
# Processing Record 2 of Set 2 | longyearbyen
# Processing Record 3 of Set 2 | kodiak
# Processing Record 4 of Set 2 | shimoda
# Processing Record 5 of Set 2 | bilma
# Processing Record 6 of Set 2 | sur
# Processing Record 7 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 8 of Set 2 | mataura
# Processing Record 9 of Set 2 | damghan
# Processing Record 10 of Set 2 | daru
# Processing Record 11 of Set 2 | codrington
# Processing Record 12 of Set 2 | jamestown
# Processing Record 13 of Set 2 | upernavik
# Processing Record 14 of Set 2 | katherine
# Processing Record 15 of Set 2 | zhigansk
# Processing Record 16 of Set 2 | padang
# Processing Record 17 of Set 2 | jacareacanga
# Processing Record 18 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 19 of Set 2 | bethanien
# Processing Record 20 of Set 2 | luwero
# Processing Record 21 of Set 2 | barrow
# Processing Record 22 of Set 2 | new norfolk
# Processing Record 23 of Set 2 | georgetown
# Processing Record 24 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 2 | voloshka
# Processing Record 26 of Set 2 | henderson
# Processing Record 27 of Set 2 | thompson
# Processing Record 28 of Set 2 | atambua
# Processing Record 29 of Set 2 | lagoa
# Processing Record 30 of Set 2 | kavieng
# Processing Record 31 of Set 2 | cherskiy
# Processing Record 32 of Set 2 | broome
# Processing Record 33 of Set 2 | quatre cocos
# Processing Record 34 of Set 2 | zachagansk
# City not found. Skipping...
# Processing Record 35 of Set 2 | atuona
# Processing Record 36 of Set 2 | koboldo
# City not found. Skipping...
# Processing Record 37 of Set 2 | gurgan
# City not found. Skipping...
# Processing Record 38 of Set 2 | albanel
# Processing Record 39 of Set 2 | hermanus
# Processing Record 40 of Set 2 | mersing
# Processing Record 41 of Set 2 | lasa
# Processing Record 42 of Set 2 | yumen
# Processing Record 43 of Set 2 | barawe
# City not found. Skipping...
# Processing Record 44 of Set 2 | cockburn town
# Processing Record 45 of Set 2 | khani
# Processing Record 46 of Set 2 | peniche
# Processing Record 47 of Set 2 | puerto del rosario
# Processing Record 48 of Set 2 | constantine
# Processing Record 49 of Set 2 | sechura
# Processing Record 50 of Set 2 | limbang
# Processing Record 1 of Set 3 | bathsheba
# Processing Record 2 of Set 3 | hobart
# Processing Record 3 of Set 3 | krasnopavlivka
# Processing Record 4 of Set 3 | qaanaaq
# Processing Record 5 of Set 3 | alofi
# Processing Record 6 of Set 3 | saint-louis
# Processing Record 7 of Set 3 | bilibino
# Processing Record 8 of Set 3 | dickinson
# Processing Record 9 of Set 3 | lebu
# Processing Record 10 of Set 3 | kichmengskiy gorodok
# Processing Record 11 of Set 3 | amurzet
# Processing Record 12 of Set 3 | ozgon
# City not found. Skipping...
# Processing Record 13 of Set 3 | locri
# Processing Record 14 of Set 3 | clarence town
# Processing Record 15 of Set 3 | chokurdakh
# Processing Record 16 of Set 3 | bacolod
# Processing Record 17 of Set 3 | ciudad bolivar
# Processing Record 18 of Set 3 | severo-kurilsk
# Processing Record 19 of Set 3 | san carlos del zulia
# Processing Record 20 of Set 3 | biak
# Processing Record 21 of Set 3 | bambous virieux
# Processing Record 22 of Set 3 | rawson
# Processing Record 23 of Set 3 | takoradi
# Processing Record 24 of Set 3 | faya
# Processing Record 25 of Set 3 | leshukonskoye
# Processing Record 26 of Set 3 | dunedin
# Processing Record 27 of Set 3 | coquimbo
# Processing Record 28 of Set 3 | castro
# Processing Record 29 of Set 3 | leningradskiy
# Processing Record 30 of Set 3 | pacific grove
# Processing Record 31 of Set 3 | rabo de peixe
# Processing Record 32 of Set 3 | tooele
# Processing Record 33 of Set 3 | buchanan
# Processing Record 34 of Set 3 | rio grande
# Processing Record 35 of Set 3 | provideniya
# Processing Record 36 of Set 3 | ponta do sol
# Processing Record 37 of Set 3 | alta floresta
# Processing Record 38 of Set 3 | kruisfontein
# Processing Record 39 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 40 of Set 3 | ilanskiy
# Processing Record 41 of Set 3 | namatanai
# Processing Record 42 of Set 3 | hilo
# Processing Record 43 of Set 3 | bardiyah
# Processing Record 44 of Set 3 | kuching
# Processing Record 45 of Set 3 | floro
# Processing Record 46 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 3 | kibaya
# Processing Record 48 of Set 3 | sobolevo
# Processing Record 49 of Set 3 | prince rupert
# Processing Record 50 of Set 3 | ostrovnoy
# Processing Record 1 of Set 4 | saskylakh
# Processing Record 2 of Set 4 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 3 of Set 4 | husavik
# Processing Record 4 of Set 4 | quelimane
# Processing Record 5 of Set 4 | le port
# Processing Record 6 of Set 4 | lavrentiya
# Processing Record 7 of Set 4 | cidreira
# Processing Record 8 of Set 4 | gamba
# Processing Record 9 of Set 4 | tahoua
# Processing Record 10 of Set 4 | briancon
# Processing Record 11 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 4 | auki
# Processing Record 13 of Set 4 | okhotsk
# Processing Record 14 of Set 4 | butaritari
# Processing Record 15 of Set 4 | baruun-urt
# Processing Record 16 of Set 4 | erdenet
# Processing Record 17 of Set 4 | kaitangata
# Processing Record 18 of Set 4 | krasnovishersk
# Processing Record 19 of Set 4 | belaya gora
# Processing Record 20 of Set 4 | hasaki
# Processing Record 21 of Set 4 | yellowknife
# Processing Record 22 of Set 4 | srednekolymsk
# Processing Record 23 of Set 4 | rorvik
# Processing Record 24 of Set 4 | pevek
# Processing Record 25 of Set 4 | palmer
# Processing Record 26 of Set 4 | esperance
# Processing Record 27 of Set 4 | pitsunda
# Processing Record 28 of Set 4 | nagram
# Processing Record 29 of Set 4 | puerto ayora
# Processing Record 30 of Set 4 | west lafayette
# Processing Record 31 of Set 4 | karkaralinsk
# City not found. Skipping...
# Processing Record 32 of Set 4 | miquelon
# Processing Record 33 of Set 4 | wenzhou
# Processing Record 34 of Set 4 | tuktoyaktuk
# Processing Record 35 of Set 4 | oranjestad
# Processing Record 36 of Set 4 | gumdag
# Processing Record 37 of Set 4 | trat
# Processing Record 38 of Set 4 | bambanglipuro
# Processing Record 39 of Set 4 | san rafael
# Processing Record 40 of Set 4 | zaraza
# Processing Record 41 of Set 4 | pemba
# Processing Record 42 of Set 4 | tuatapere
# Processing Record 43 of Set 4 | havelock
# Processing Record 44 of Set 4 | kahului
# Processing Record 45 of Set 4 | talnakh
# Processing Record 46 of Set 4 | hambantota
# Processing Record 47 of Set 4 | yulara
# Processing Record 48 of Set 4 | chapais
# Processing Record 49 of Set 4 | ust-omchug
# Processing Record 50 of Set 4 | armacao dos buzios
# City not found. Skipping...
# Processing Record 1 of Set 5 | vostok
# Processing Record 2 of Set 5 | kaeo
# Processing Record 3 of Set 5 | emerald
# Processing Record 4 of Set 5 | kelo
# Processing Record 5 of Set 5 | kamaishi
# Processing Record 6 of Set 5 | lompoc
# Processing Record 7 of Set 5 | satitoa
# City not found. Skipping...
# Processing Record 8 of Set 5 | dourbali
# Processing Record 9 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 10 of Set 5 | pabrade
# Processing Record 11 of Set 5 | macon
# Processing Record 12 of Set 5 | ormara
# Processing Record 13 of Set 5 | madaoua
# Processing Record 14 of Set 5 | sola
# Processing Record 15 of Set 5 | gornopravdinsk
# Processing Record 16 of Set 5 | sogne
# Processing Record 17 of Set 5 | ribeira grande
# Processing Record 18 of Set 5 | guarda
# Processing Record 19 of Set 5 | labuhan
# Processing Record 20 of Set 5 | roald
# Processing Record 21 of Set 5 | halifax
# Processing Record 22 of Set 5 | buala
# Processing Record 23 of Set 5 | lahad datu
# Processing Record 24 of Set 5 | lingao
# Processing Record 25 of Set 5 | sitka
# Processing Record 26 of Set 5 | kendari
# Processing Record 27 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 28 of Set 5 | walvis bay
# Processing Record 29 of Set 5 | geraldton
# Processing Record 30 of Set 5 | caravelas
# Processing Record 31 of Set 5 | nardaran
# Processing Record 32 of Set 5 | dakar
# Processing Record 33 of Set 5 | saint george
# Processing Record 34 of Set 5 | saldanha
# Processing Record 35 of Set 5 | tautira
# Processing Record 36 of Set 5 | christchurch
# Processing Record 37 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 38 of Set 5 | chuy
# Processing Record 39 of Set 5 | kharp
# Processing Record 40 of Set 5 | port alfred
# Processing Record 41 of Set 5 | winslow
# Processing Record 42 of Set 5 | karlstad
# Processing Record 43 of Set 5 | arlit
# Processing Record 44 of Set 5 | kesova gora
# Processing Record 45 of Set 5 | whitehorse
# Processing Record 46 of Set 5 | yeniseysk
# Processing Record 47 of Set 5 | dzhusaly
# City not found. Skipping...
# Processing Record 48 of Set 5 | harbour breton
# Processing Record 49 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 50 of Set 5 | karaton
# Processing Record 1 of Set 6 | atasu
# Processing Record 2 of Set 6 | kijang
# Processing Record 3 of Set 6 | lensk
# Processing Record 4 of Set 6 | wahiawa
# Processing Record 5 of Set 6 | kudahuvadhoo
# Processing Record 6 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 7 of Set 6 | simbahan
# Processing Record 8 of Set 6 | obo
# Processing Record 9 of Set 6 | paradwip
# City not found. Skipping...
# Processing Record 10 of Set 6 | richards bay
# Processing Record 11 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 6 | saint-georges
# Processing Record 13 of Set 6 | yarega
# Processing Record 14 of Set 6 | conde
# Processing Record 15 of Set 6 | braganca
# Processing Record 16 of Set 6 | loganville
# Processing Record 17 of Set 6 | zaterechnyy
# Processing Record 18 of Set 6 | impfondo
# Processing Record 19 of Set 6 | margate
# Processing Record 20 of Set 6 | yuanping
# Processing Record 21 of Set 6 | qidong
# Processing Record 22 of Set 6 | beberibe
# Processing Record 23 of Set 6 | juneau
# Processing Record 24 of Set 6 | mount isa
# Processing Record 25 of Set 6 | solsvik
# City not found. Skipping...
# Processing Record 26 of Set 6 | boa vista
# Processing Record 27 of Set 6 | road town
# Processing Record 28 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 29 of Set 6 | svetlyy
# Processing Record 30 of Set 6 | soldotna
# Processing Record 31 of Set 6 | palembang
# Processing Record 32 of Set 6 | port lincoln
# Processing Record 33 of Set 6 | bowen
# Processing Record 34 of Set 6 | cuamba
# Processing Record 35 of Set 6 | petersburg
# Processing Record 36 of Set 6 | portland
# Processing Record 37 of Set 6 | lata
# Processing Record 38 of Set 6 | olafsvik
# Processing Record 39 of Set 6 | port-gentil
# Processing Record 40 of Set 6 | kerema
# Processing Record 41 of Set 6 | la union
# Processing Record 42 of Set 6 | kralendijk
# Processing Record 43 of Set 6 | raudeberg
# Processing Record 44 of Set 6 | grand gaube
# Processing Record 45 of Set 6 | ada
# Processing Record 46 of Set 6 | tasiilaq
# Processing Record 47 of Set 6 | cham
# Processing Record 48 of Set 6 | maningrida
# Processing Record 49 of Set 6 | natal
# Processing Record 50 of Set 6 | constitucion
# Processing Record 1 of Set 7 | betioky
# Processing Record 2 of Set 7 | dmitrov
# Processing Record 3 of Set 7 | roma
# Processing Record 4 of Set 7 | victoria
# Processing Record 5 of Set 7 | banjar
# Processing Record 6 of Set 7 | mar del plata
# Processing Record 7 of Set 7 | havoysund
# Processing Record 8 of Set 7 | beidao
# Processing Record 9 of Set 7 | porto velho
# Processing Record 10 of Set 7 | avarua
# Processing Record 11 of Set 7 | beni suef
# Processing Record 12 of Set 7 | iqaluit
# Processing Record 13 of Set 7 | mulege
# Processing Record 14 of Set 7 | menongue
# Processing Record 15 of Set 7 | seoul
# Processing Record 16 of Set 7 | port blair
# Processing Record 17 of Set 7 | cayenne
# Processing Record 18 of Set 7 | mirpur khas
# Processing Record 19 of Set 7 | tunxi
# City not found. Skipping...
# Processing Record 20 of Set 7 | khotynets
# Processing Record 21 of Set 7 | abomsa
# Processing Record 22 of Set 7 | mpulungu
# Processing Record 23 of Set 7 | batemans bay
# Processing Record 24 of Set 7 | bloomingdale
# Processing Record 25 of Set 7 | saint-augustin
# Processing Record 26 of Set 7 | ndioum
# Processing Record 27 of Set 7 | charlestown
# Processing Record 28 of Set 7 | abu samrah
# Processing Record 29 of Set 7 | alakurtti
# Processing Record 30 of Set 7 | tacoronte
# Processing Record 31 of Set 7 | ingham
# Processing Record 32 of Set 7 | qaqortoq
# Processing Record 33 of Set 7 | fereydunshahr
# Processing Record 34 of Set 7 | clyde
# Processing Record 35 of Set 7 | porto torres
# Processing Record 36 of Set 7 | korla
# Processing Record 37 of Set 7 | charters towers
# Processing Record 38 of Set 7 | bolshoye nagatkino
# Processing Record 39 of Set 7 | sisimiut
# Processing Record 40 of Set 7 | merrill
# Processing Record 41 of Set 7 | vardo
# Processing Record 42 of Set 7 | san carlos de bariloche
# Processing Record 43 of Set 7 | golubitskaya
# Processing Record 44 of Set 7 | haibowan
# City not found. Skipping...
# Processing Record 45 of Set 7 | camopi
# Processing Record 46 of Set 7 | ancud
# Processing Record 47 of Set 7 | saint anthony
# Processing Record 48 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 49 of Set 7 | shunyi
# Processing Record 50 of Set 7 | ballachulish
# Processing Record 1 of Set 8 | bossangoa
# Processing Record 2 of Set 8 | isangel
# Processing Record 3 of Set 8 | licata
# Processing Record 4 of Set 8 | polaniec
# Processing Record 5 of Set 8 | hualmay
# Processing Record 6 of Set 8 | stoyba
# City not found. Skipping...
# Processing Record 7 of Set 8 | ilulissat
# Processing Record 8 of Set 8 | xunchang
# Processing Record 9 of Set 8 | woodward
# Processing Record 10 of Set 8 | kluang
# Processing Record 11 of Set 8 | sirjan
# Processing Record 12 of Set 8 | coos bay
# Processing Record 13 of Set 8 | klaksvik
# Processing Record 14 of Set 8 | vila velha
# Processing Record 15 of Set 8 | palasa
# Processing Record 16 of Set 8 | russell
# Processing Record 17 of Set 8 | tessalit
# Processing Record 18 of Set 8 | muzhi
# Processing Record 19 of Set 8 | huilong
# Processing Record 20 of Set 8 | liepaja
# Processing Record 21 of Set 8 | nome
# Processing Record 22 of Set 8 | bac lieu
# Processing Record 23 of Set 8 | leh
# Processing Record 24 of Set 8 | bengkulu
# Processing Record 25 of Set 8 | salinas
# Processing Record 26 of Set 8 | veshkayma
# Processing Record 27 of Set 8 | tabory
# Processing Record 28 of Set 8 | nanhai
# Processing Record 29 of Set 8 | umm lajj
# Processing Record 30 of Set 8 | tiblawan
# Processing Record 31 of Set 8 | puerto escondido
# Processing Record 32 of Set 8 | itupiranga
# Processing Record 33 of Set 8 | humaita
# Processing Record 34 of Set 8 | deep river
# Processing Record 35 of Set 8 | oberstdorf
# Processing Record 36 of Set 8 | nishihara
# Processing Record 37 of Set 8 | honiara
# Processing Record 38 of Set 8 | sinjah
# City not found. Skipping...
# Processing Record 39 of Set 8 | katsuura
# Processing Record 40 of Set 8 | rock springs
# Processing Record 41 of Set 8 | ketchikan
# Processing Record 42 of Set 8 | cabedelo
# Processing Record 43 of Set 8 | sept-iles
# Processing Record 44 of Set 8 | zhaoyuan
# Processing Record 45 of Set 8 | dori
# Processing Record 46 of Set 8 | asau
# Processing Record 47 of Set 8 | kungurtug
# Processing Record 48 of Set 8 | clyde river
# Processing Record 49 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 50 of Set 8 | sao miguel do araguaia
# Processing Record 1 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 9 | puerto quijarro
# Processing Record 3 of Set 9 | jiayuguan
# Processing Record 4 of Set 9 | saint-pierre
# Processing Record 5 of Set 9 | taga dzong
# City not found. Skipping...
# Processing Record 6 of Set 9 | sedelnikovo
# City not found. Skipping...
# Processing Record 7 of Set 9 | pangody
# Processing Record 8 of Set 9 | komsomolets
# Processing Record 9 of Set 9 | tutoia
# Processing Record 10 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 9 | beloha
# Processing Record 12 of Set 9 | port-cartier
# Processing Record 13 of Set 9 | ballina
# Processing Record 14 of Set 9 | watertown
# Processing Record 15 of Set 9 | vershino-darasunskiy
# Processing Record 16 of Set 9 | dongsheng
# Processing Record 17 of Set 9 | alotau
# City not found. Skipping...
# Processing Record 18 of Set 9 | general roca
# Processing Record 19 of Set 9 | hendijan
# City not found. Skipping...
# Processing Record 20 of Set 9 | istanbul
# Processing Record 21 of Set 9 | henties bay
# Processing Record 22 of Set 9 | monte cristi
# City not found. Skipping...
# Processing Record 23 of Set 9 | karasuk
# Processing Record 24 of Set 9 | airai
# Processing Record 25 of Set 9 | kenai
# Processing Record 26 of Set 9 | la ronge
# Processing Record 27 of Set 9 | hohhot
# Processing Record 28 of Set 9 | san patricio
# Processing Record 29 of Set 9 | ukiah
# Processing Record 30 of Set 9 | souillac
# Processing Record 31 of Set 9 | guozhen
# Processing Record 32 of Set 9 | shchelyayur
# City not found. Skipping...
# Processing Record 33 of Set 9 | oyama
# Processing Record 34 of Set 9 | chifeng
# Processing Record 35 of Set 9 | colares
# Processing Record 36 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 37 of Set 9 | benghazi
# Processing Record 38 of Set 9 | envira
# Processing Record 39 of Set 9 | grand-lahou
# Processing Record 40 of Set 9 | manaus
# Processing Record 41 of Set 9 | tripoli
# Processing Record 42 of Set 9 | itarema
# Processing Record 43 of Set 9 | buraydah
# Processing Record 44 of Set 9 | bintulu
# Processing Record 45 of Set 9 | manakara
# Processing Record 46 of Set 9 | huarmey
# Processing Record 47 of Set 9 | uray
# Processing Record 48 of Set 9 | maba
# Processing Record 49 of Set 9 | fort nelson
# Processing Record 50 of Set 9 | mahanje
# Processing Record 1 of Set 10 | batagay-alyta
# Processing Record 2 of Set 10 | grasse
# Processing Record 3 of Set 10 | rio gallegos
# Processing Record 4 of Set 10 | acarau
# Processing Record 5 of Set 10 | altay
# Processing Record 6 of Set 10 | milledgeville
# Processing Record 7 of Set 10 | catuday
# Processing Record 8 of Set 10 | svarstad
# Processing Record 9 of Set 10 | tual
# Processing Record 10 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 11 of Set 10 | brest
# Processing Record 12 of Set 10 | cam ranh
# Processing Record 13 of Set 10 | malanje
# Processing Record 14 of Set 10 | mae hong son
# Processing Record 15 of Set 10 | nemuro
# Processing Record 16 of Set 10 | todos santos
# Processing Record 17 of Set 10 | sorland
# Processing Record 18 of Set 10 | cooma
# Processing Record 19 of Set 10 | nargana
# Processing Record 20 of Set 10 | sao filipe
# Processing Record 21 of Set 10 | bukan
# Processing Record 22 of Set 10 | cap malheureux
# Processing Record 23 of Set 10 | gizo
# Processing Record 24 of Set 10 | coihaique
# Processing Record 25 of Set 10 | wajima
# Processing Record 26 of Set 10 | nuuk
# Processing Record 27 of Set 10 | yerofey pavlovich
# Processing Record 28 of Set 10 | minna
# Processing Record 29 of Set 10 | wukari
# Processing Record 30 of Set 10 | pochutla
# Processing Record 31 of Set 10 | matay
# Processing Record 32 of Set 10 | shenjiamen
# Processing Record 33 of Set 10 | akcaabat
# Processing Record 34 of Set 10 | saurimo
# Processing Record 35 of Set 10 | luau
# Processing Record 36 of Set 10 | whyalla
# Processing Record 37 of Set 10 | dubovyy umet
# Processing Record 38 of Set 10 | solnechnyy
# Processing Record 39 of Set 10 | ojinaga
# Processing Record 40 of Set 10 | igarka
# Processing Record 41 of Set 10 | teknaf
# Processing Record 42 of Set 10 | lixourion
# Processing Record 43 of Set 10 | kiama
# Processing Record 44 of Set 10 | karacabey
# Processing Record 45 of Set 10 | nyurba
# Processing Record 46 of Set 10 | alashtar
# City not found. Skipping...
# Processing Record 47 of Set 10 | sharjah
# Processing Record 48 of Set 10 | naze
# Processing Record 49 of Set 10 | manjacaze
# Processing Record 50 of Set 10 | tigil
# Processing Record 1 of Set 11 | dwarka
# Processing Record 2 of Set 11 | barranca
# Processing Record 3 of Set 11 | amparafaravola
# Processing Record 4 of Set 11 | tambul
# City not found. Skipping...
# Processing Record 5 of Set 11 | port hedland
# Processing Record 6 of Set 11 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 7 of Set 11 | xining
# Processing Record 8 of Set 11 | vila
# Processing Record 9 of Set 11 | aykhal
# Processing Record 10 of Set 11 | nova granada
# Processing Record 11 of Set 11 | kurkino
# Processing Record 12 of Set 11 | asyut
# Processing Record 13 of Set 11 | nouadhibou
# Processing Record 14 of Set 11 | wuwei
# Processing Record 15 of Set 11 | nabire
# Processing Record 16 of Set 11 | vestmannaeyjar
# Processing Record 17 of Set 11 | klyuchi
# Processing Record 18 of Set 11 | sciacca
# Processing Record 19 of Set 11 | kirakira
# Processing Record 20 of Set 11 | nelson bay
# Processing Record 21 of Set 11 | milkovo
# Processing Record 22 of Set 11 | xifeng
# Processing Record 23 of Set 11 | kapustin yar
# Processing Record 24 of Set 11 | miandoab
# Processing Record 25 of Set 11 | zhuanghe
# Processing Record 26 of Set 11 | grahamstown
# Processing Record 27 of Set 11 | inuvik
# Processing Record 28 of Set 11 | mezen
# Processing Record 29 of Set 11 | san isidro
# Processing Record 30 of Set 11 | mucuri
# Processing Record 31 of Set 11 | san jeronimo
# Processing Record 32 of Set 11 | kavaratti
# Processing Record 33 of Set 11 | labuan
# Processing Record 34 of Set 11 | tupik
# Processing Record 35 of Set 11 | deputatskiy
# Processing Record 36 of Set 11 | umm durman
# City not found. Skipping...
# Processing Record 37 of Set 11 | olsztyn
# Processing Record 38 of Set 11 | inhambane
# Processing Record 39 of Set 11 | fortuna
# Processing Record 40 of Set 11 | mutoko
# Processing Record 41 of Set 11 | taltal
# Processing Record 42 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 43 of Set 11 | pierre
# Processing Record 44 of Set 11 | nikolayevka
# Processing Record 45 of Set 11 | aklavik
# Processing Record 46 of Set 11 | vanimo
# Processing Record 47 of Set 11 | algiers
# Processing Record 48 of Set 11 | terme
# Processing Record 49 of Set 11 | usolye
# Processing Record 50 of Set 11 | dawei
# Processing Record 1 of Set 12 | bandarbeyla
# Processing Record 2 of Set 12 | yanam
# Processing Record 3 of Set 12 | touros
# Processing Record 4 of Set 12 | corinto
# Processing Record 5 of Set 12 | mpika
# Processing Record 6 of Set 12 | shache
# Processing Record 7 of Set 12 | innisfail
# Processing Record 8 of Set 12 | paamiut
# Processing Record 9 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 10 of Set 12 | beringovskiy
# Processing Record 11 of Set 12 | olinda
# Processing Record 12 of Set 12 | enterprise
# Processing Record 13 of Set 12 | eureka
# Processing Record 14 of Set 12 | ilo
# Processing Record 15 of Set 12 | acuna
# City not found. Skipping...
# Processing Record 16 of Set 12 | saint-francois
# Processing Record 17 of Set 12 | hope mills
# Processing Record 18 of Set 12 | chapleau
# Processing Record 19 of Set 12 | inzer
# Processing Record 20 of Set 12 | sambava
# Processing Record 21 of Set 12 | solovetskiy
# City not found. Skipping...
# Processing Record 22 of Set 12 | moerai
# Processing Record 23 of Set 12 | imbituba
# Processing Record 24 of Set 12 | anshun
# Processing Record 25 of Set 12 | tabou
# Processing Record 26 of Set 12 | kutahya
# Processing Record 27 of Set 12 | east london
# Processing Record 28 of Set 12 | udachnyy
# Processing Record 29 of Set 12 | shashi
# Processing Record 30 of Set 12 | bogoslovka
# Processing Record 31 of Set 12 | salgotarjan
# Processing Record 32 of Set 12 | coria del rio
# Processing Record 33 of Set 12 | tateyama
# Processing Record 34 of Set 12 | makakilo city
# Processing Record 35 of Set 12 | tortoli
# Processing Record 36 of Set 12 | methoni
# Processing Record 37 of Set 12 | sao joao da barra
# Processing Record 38 of Set 12 | atar
# Processing Record 39 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 40 of Set 12 | prince george
# Processing Record 41 of Set 12 | kemin
# Processing Record 42 of Set 12 | jinchengjiang
# City not found. Skipping...
# Processing Record 43 of Set 12 | kampot
# Processing Record 44 of Set 12 | yenotayevka
# Processing Record 45 of Set 12 | nanlong
# Processing Record 46 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 47 of Set 12 | kloulklubed
# Processing Record 48 of Set 12 | oudtshoorn
# Processing Record 49 of Set 12 | karaman
# Processing Record 50 of Set 12 | turukhansk
# Processing Record 1 of Set 13 | sibiti
# Processing Record 2 of Set 13 | uitenhage
# Processing Record 3 of Set 13 | anda
# Processing Record 4 of Set 13 | tefe
# Processing Record 5 of Set 13 | muros
# Processing Record 6 of Set 13 | soyo
# Processing Record 7 of Set 13 | vila franca do campo
# Processing Record 8 of Set 13 | zhezkazgan
# Processing Record 9 of Set 13 | skjervoy
# Processing Record 10 of Set 13 | yarada
# Processing Record 11 of Set 13 | santander
# Processing Record 12 of Set 13 | lazaro cardenas
# Processing Record 13 of Set 13 | waddan
# Processing Record 14 of Set 13 | kamphaeng phet
# Processing Record 15 of Set 13 | hellvik
# Processing Record 16 of Set 13 | sistranda
# Processing Record 17 of Set 13 | mecca
# Processing Record 18 of Set 13 | opuwo
# Processing Record 19 of Set 13 | praxedis guerrero
# Processing Record 20 of Set 13 | dzerzhinsk
# Processing Record 21 of Set 13 | hamilton
# Processing Record 22 of Set 13 | monte patria
# Processing Record 23 of Set 13 | taywarah
# Processing Record 24 of Set 13 | hervey bay
# Processing Record 25 of Set 13 | plettenberg bay
# Processing Record 26 of Set 13 | kamenka
# Processing Record 27 of Set 13 | salmas
# Processing Record 28 of Set 13 | shetpe
# Processing Record 29 of Set 13 | omboue
# Processing Record 30 of Set 13 | manzhouli
# Processing Record 31 of Set 13 | mao
# Processing Record 32 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 33 of Set 13 | guarapari
# Processing Record 34 of Set 13 | hovd
# Processing Record 35 of Set 13 | palauig
# Processing Record 36 of Set 13 | sinnamary
# Processing Record 37 of Set 13 | dano
# Processing Record 38 of Set 13 | salinopolis
# Processing Record 39 of Set 13 | ryotsu
# Processing Record 40 of Set 13 | hun
# Processing Record 41 of Set 13 | ibaiti
# Processing Record 42 of Set 13 | port hardy
# Processing Record 43 of Set 13 | kvarkeno
# Processing Record 44 of Set 13 | lyubeshiv
# City not found. Skipping...
# Processing Record 45 of Set 13 | oni
# Processing Record 46 of Set 13 | mnogovershinnyy
# Processing Record 47 of Set 13 | heinola
# Processing Record 48 of Set 13 | wilmington
# Processing Record 49 of Set 13 | carbonia
# Processing Record 50 of Set 13 | velez-malaga
# Processing Record 1 of Set 14 | osorno
# Processing Record 2 of Set 14 | cockburn harbour
# City not found. Skipping...
# Processing Record 3 of Set 14 | necochea
# Processing Record 4 of Set 14 | mableton
# Processing Record 5 of Set 14 | capinopolis
# Processing Record 6 of Set 14 | santa cruz
# Processing Record 7 of Set 14 | bontang
# Processing Record 8 of Set 14 | coari
# Processing Record 9 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 10 of Set 14 | tamandare
# Processing Record 11 of Set 14 | kovdor
# Processing Record 12 of Set 14 | iralaya
# Processing Record 13 of Set 14 | maralal
# Processing Record 14 of Set 14 | khuzdar
# Processing Record 15 of Set 14 | promyshlennyy
# Processing Record 16 of Set 14 | wagar
# Processing Record 17 of Set 14 | chokwe
# Processing Record 18 of Set 14 | samusu
# City not found. Skipping...
# Processing Record 19 of Set 14 | strezhevoy
# Processing Record 20 of Set 14 | bosaso
# Processing Record 21 of Set 14 | la crosse
# Processing Record 22 of Set 14 | gagnoa
# Processing Record 23 of Set 14 | aban
# Processing Record 24 of Set 14 | gropnita
# Processing Record 25 of Set 14 | barbar
# City not found. Skipping...
# Processing Record 26 of Set 14 | ust-koksa
# Processing Record 27 of Set 14 | shubarshi
# Processing Record 28 of Set 14 | tubuala
# Processing Record 29 of Set 14 | grindavik
# Processing Record 30 of Set 14 | whitley bay
# Processing Record 31 of Set 14 | berdigestyakh
# Processing Record 32 of Set 14 | zolotukhino
# Processing Record 33 of Set 14 | vinh
# Processing Record 34 of Set 14 | rosario
# Processing Record 35 of Set 14 | alexandria
# Processing Record 36 of Set 14 | avera
# Processing Record 37 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 38 of Set 14 | xam nua
# Processing Record 39 of Set 14 | goya
# Processing Record 40 of Set 14 | sumenep
# Processing Record 41 of Set 14 | hofn
# Processing Record 42 of Set 14 | jalu
# Processing Record 43 of Set 14 | ixtapa
# Processing Record 44 of Set 14 | bubaque
# Processing Record 45 of Set 14 | qandala
# Processing Record 46 of Set 14 | broken hill
# Processing Record 47 of Set 14 | zhoucheng
# Processing Record 48 of Set 14 | lamu
# Processing Record 49 of Set 14 | coahuayana
# Processing Record 50 of Set 14 | alice springs
# Processing Record 1 of Set 15 | kaniama
# Processing Record 2 of Set 15 | leninsk
# Processing Record 3 of Set 15 | shakawe
# Processing Record 4 of Set 15 | ishigaki
# Processing Record 5 of Set 15 | mach
# Processing Record 6 of Set 15 | cuyotenango
# Processing Record 7 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 8 of Set 15 | ouesso
# Processing Record 9 of Set 15 | saposoa
# Processing Record 10 of Set 15 | bondo
# Processing Record 11 of Set 15 | chicama
# Processing Record 12 of Set 15 | tondano
# Processing Record 13 of Set 15 | arandis
# Processing Record 14 of Set 15 | kuloy
# Processing Record 15 of Set 15 | nuevo progreso
# Processing Record 16 of Set 15 | camacha
# Processing Record 17 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 18 of Set 15 | krasnoarmeysk
# Processing Record 19 of Set 15 | ostroleka
# Processing Record 20 of Set 15 | dingle
# Processing Record 21 of Set 15 | mangochi
# Processing Record 22 of Set 15 | sarakhs
# Processing Record 23 of Set 15 | coracao de maria
# Processing Record 24 of Set 15 | tomatlan
# Processing Record 25 of Set 15 | torrevieja
# Processing Record 26 of Set 15 | los llanos de aridane
# Processing Record 27 of Set 15 | ozernovskiy
# Processing Record 28 of Set 15 | bandar-e lengeh
# Processing Record 29 of Set 15 | dedza
# Processing Record 30 of Set 15 | luwuk
# Processing Record 31 of Set 15 | kirtipur
# Processing Record 32 of Set 15 | dodge city
# Processing Record 33 of Set 15 | rolim de moura
# City not found. Skipping...
# Processing Record 34 of Set 15 | nurota
# Processing Record 35 of Set 15 | krasnoselkup
# Processing Record 36 of Set 15 | andevoranto
# City not found. Skipping...
# Processing Record 37 of Set 15 | pisco
# Processing Record 38 of Set 15 | grimshaw
# Processing Record 39 of Set 15 | reforma
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %%
len(city_data)
# Out:
# 674

# %%
#Create a city df
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Bethel      US  41.3712  -73.4140     42.04        61           1
# 1           Dikson      RU  73.5069   80.5464     -6.14        94          99
# 2          Ushuaia      AR -54.8000  -68.3000     34.05        91           7
# 3          Rikitea      PF -23.1203 -134.9692     73.76        65          25
# 4     Punta Arenas      CL -53.1500  -70.9167     46.11        75          70
# 5           Evensk      RU  61.9500  159.2333     21.04        82         100
# 6            Bluff      NZ -46.6000  168.3333     52.07        83          99
# 7        Busselton      AU -33.6500  115.3333     72.05        48           7
# 8          Te Anau      NZ -45.4167  167.7167     53.56        95         100
# 9  Arraial Do Cabo      BR -22.9661  -42.0278     73.11        94         100
#
#    Wind Speed Current Description
# 0        1.01           clear sky
# 1        3.71     overcast clouds
# 2        3.89           clear sky
# 3        9.42    scattered clouds
# 4       26.75       broken clouds
# 5       16.15     overcast clouds
# 6        2.13     overcast clouds
# 7        8.01           clear sky
# 8        4.54     overcast clouds
# 9       16.02     overcast clouds

# %%
new_column_order = ["City","Country","Lat","Lng", "Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Bethel      US  41.3712  -73.4140     42.04        61           1
# 1          Dikson      RU  73.5069   80.5464     -6.14        94          99
# 2         Ushuaia      AR -54.8000  -68.3000     34.05        91           7
# 3         Rikitea      PF -23.1203 -134.9692     73.76        65          25
# 4    Punta Arenas      CL -53.1500  -70.9167     46.11        75          70
# ..            ...     ...      ...       ...       ...       ...         ...
# 669        Nurota      UZ  40.5614   65.6886     24.89        52           0
# 670  Krasnoselkup      RU  65.7000   82.4667    -15.54        96          18
# 671         Pisco      PE -13.7000  -76.2167     65.01        88           0
# 672      Grimshaw      CA  56.1834 -117.6027     13.62        85          90
# 673       Reforma      MX  18.1000  -91.0167     72.46        95         100
#
#      Wind Speed Current Description
# 0          1.01           clear sky
# 1          3.71     overcast clouds
# 2          3.89           clear sky
# 3          9.42    scattered clouds
# 4         26.75       broken clouds
# ..          ...                 ...
# 669        2.08           clear sky
# 670       10.80          few clouds
# 671        9.22           clear sky
# 672       18.41          light snow
# 673        5.46     overcast clouds
#
# [674 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
